# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio


data = pd.read_csv('DioxIA.csv', sep=',')

data['Type de point de mesure'].replace({"source":"Source"}, inplace=True)

# %%
len(data[data['Fournisseur']!="US EPA"])
# Out:
# 789

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(data.isnull().sum())
# Out:
# Fournisseur                            67
# Nom du projet                           0
# Réf. échantillon                        2
# Réf. Synthese                        1474
# Coord. Lat. Source                     43
# Coord. Long. Source                    43
# Localisation de la source              43
# Coord. Lat. Point                    1411
# Coord. Long. Point                   1411
# Distance à la source (km)              60
# Typologie de l'emplacement             38
# Type de point de mesure               117
# Fiabilité donnée de l'emplacement     101
# Complément                           1324
# Date de mesure :  Début               115
# Date de mesure :  Fin                 115
# Année                                  12
# Source                                 35
# Contexte                               35
# Matrice                                 0
# Direction des vents dominants         142
# Direction des vents secondaires       142
# Force des vents  (m/s)                142
# Pluviométrie (mm/min)                 142
# Température (°C)                      142
# Humidité Relative %                   142
# Gestion Limite Analytique               0
# Unités                                  0
# Somme PCDD                              0
# 2378-TCDD                               0
# <                                     817
# 12378-PCDD                              0
# <.1                                   911
# 123478-HxCDD                            0
# <.2                                   918
# 123678-HxCDD                            0
# <.3                                  1087
# 123789-HxCDD                            0
# <.4                                  1051
# 1234678-HpCDD                           0
# <.5                                  1391
# OCDD                                    0
# <.6                                  1403
# Somme PCDF                              0
# 2378-TCDF                               1
# <.7                                  1191
# 12378-PeCDF                             0
# <.8                                  1074
# 23478-PeCDF                             0
# <.9                                  1162
# 123478-HxCDF                            0
# <.10                                 1151
# 123678-HxCDF                            0
# <.11                                 1142
# 234678-HxCDF                            0
# <.12                                 1193
# 123789-HxCDF                            0
# <.13                                  721
# 1234678-HpCDF                           0
# <.14                                 1364
# 1234789-HpCDF                           0
# <.15                                 1020
# OCDF                                    0
# <.16                                 1289
# Somme PCDD-PCDF                         0
# Total TCDD                            327
# <.17                                 1354
# Total PeCDD                           327
# <.18                                 1322
# Total HxCDD                           327
# <.19                                 1387
# Total HpCDD                           327
# <.20                                 1424
# Total DIOXINE                         291
# <.21                                 1410
# Total TCDF                            327
# <.22                                 1361
# Total PeCDF                           327
# <.23                                 1346
# Total HxCDF                           327
# <.24                                 1364
# Total HpCDF                           327
# <.25                                 1400
# Total FURANE                          291
# <.26                                 1427
# Total DIOXINE FURANE                    0
# Commentaire                          1417
# dtype: int64

# %%
col = "Fournisseur"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Nom du projet"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Distance à la source (km)"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Type de point de mesure"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Fiabilité donnée de l'emplacement"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Source"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Contexte"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Matrice"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Unités"
f,ax=plt.subplots(1,2,figsize=(18,8))
data[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
data_ = data[data['Fournisseur']!='US EPA']

# %%
col = "Fournisseur"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Nom du projet"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Distance à la source (km)"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Type de point de mesure"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Fiabilité donnée de l'emplacement"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Source"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Contexte"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Matrice"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
col = "Unités"
f,ax=plt.subplots(1,2,figsize=(18,8))
data_[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title(col)
ax[0].set_ylabel('')
sns.countplot(col,data=data_,ax=ax[1])
ax[1].set_title(col)
ax[1].tick_params(labelrotation=45)
plt.show()

# %%
data.describe()
# Out:
#        Réf. Synthese
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
data.columns
# Out:
# Index(['Site', 'Type', 'Season', 'Site #', 'Moment', '2378-TCDD_A',
#        '12378-PCDD_A', '123478-HxCDD_A', '123678-HxCDD_A', '123789-HxCDD_A',
#        '1234678-HpCDD_A', 'OCDD_A', '2378-TCDF_A', '12378-PeCDF_A',
#        '23478-PeCDF_A', '123478-HxCDF_A', '123678-HxCDF_A', '234678-HxCDF_A',
#        '123789-HxCDF_A', '1234678-HpCDF_A', '1234789-HpCDF_A', 'OCDF_A',
#        '2378-TCDD_C', '12378-PCDD_C', '123478-HxCDD_C', '123678-HxCDD_C',
#        '123789-HxCDD_C', '1234678-HpCDD_C', 'OCDD_C', '2378-TCDF_C',
#        '12378-PeCDF_C', '23478-PeCDF_C', '123478-HxCDF_C', '123678-HxCDF_C',
#        '234678-HxCDF_C', '123789-HxCDF_C', '1234678-HpCDF_C',
#        '1234789-HpCDF_C', 'OCDF_C'],
#       dtype='object')
